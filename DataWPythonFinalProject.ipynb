# %% [markdown]
# # Data w/ Python Final Project

# %% [markdown]
# ## Extract Data

# %%
# Importing Libraries
import requests
import pandas as pd

# %%
# Making API call that returns the full dataset
url='https://data.sfgov.org/resource/ubqf-aqzw.json?$$app_token=JOZ8TqBETX5dP2rEWVV3hoKgo'
params={'$limit': '261874'}
r=requests.get(url,params=params)
r=r.json()
r
# Out:
# [{'doj_record_id': 'U3801182212099D51C75',
#   'person_number': '1',
#   'unique_identifier': 'U3801182212099D51C75_1',
#   'stop_data_record_status': 'Completed - Successful Submission',
#   'agency_ori': 'CA0380100',
#   'stop_datetime': '2018-08-09T16:05:00.000',
#   'duration_of_stop': '4',
#   'is_stop_response_to_call': 'N',
#   'location': 'BRYANT ST & 2ND ST',
#   'district': 'SOUTHERN',
#   'city': 'SAN FRANCISCO',
#   'perceived_race_ethnicity': 'Asian',
#   'perceived_gender': 'Female',
#   'is_lgbt': 'N',
#   'perceived_age': '50',
#   'perceived_age_group': '50 - 59',
#   'had_limited_or_no_english': 'N',
#   'perceived_or_known_disability': 'None',
#   'if_k12_school_is_student': 'N',
#   'reason_for_stop': 'Traffic violation',
#   'traffic_violation_type': 'Moving violation',
#   'traffic_viol_cjis_off_code': '54114',
#   'traffic_viol_off_code': 'FT/YIELD BE4 LEFT/U-TURN',
#   'traffic_viol_off_statute': '21801(A)',
#   'traffic_viol_off_type': 'VC',
# ...

# %%
# Verifiying that full API JSON response is returned
len(r)
# Out:
# 261874

# %%
# Checking to see if API JSON response needs to be converted into a list before being converted into a Pandas DataFrame
print(type(r))
# Out:
# <class 'list'>

# %%
# Converting San Francisco API JSON response into a DataFrame
df=pd.DataFrame(r)
df
# Out:
#                doj_record_id person_number       unique_identifier  \
# 0       U3801182212099D51C75             1  U3801182212099D51C75_1
# 1       U38011822213C974B0F8             1  U38011822213C974B0F8_1
# 2       U3801182217DE44A11D0             1  U3801182217DE44A11D0_1
# 3       U3801182216E4F98E00B             1  U3801182216E4F98E00B_1
# 4       U380118222EAA40B9919             1  U380118222EAA40B9919_1
# ...                      ...           ...                     ...
# 261869  U3801202744AEBE53ADA             6  U3801202744AEBE53ADA_6
# 261870  U38012223529515786D7             4  U38012223529515786D7_4
# 261871  U3801222358CEA13C6A5             4  U3801222358CEA13C6A5_4
# 261872  U3801222353D9DC2C45C             4  U3801222353D9DC2C45C_4
# 261873  U3801222595268195966             4  U3801222595268195966_4
#
#                   stop_data_record_status agency_ori            stop_datetime  \
# 0       Completed - Successful Submission  CA0380100  2018-08-09T16:05:00.000
# ...

# %%
# Ingesting Rhode Island Kaggle Dataset and creating another dataframe
df2=pd.read_csv('/home/mariahwarren/police_project.csv/police_project.csv')
df2
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %% [markdown]
# ## Transforming Data

# %%
# Checking Data Types and Null Values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261874 entries, 0 to 261873
# Data columns (total 83 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   doj_record_id                        250093 non-null  object
#  1   person_number                        261435 non-null  object
#  2   unique_identifier                    261874 non-null  object
#  3   stop_data_record_status              261874 non-null  object
#  4   agency_ori                           261874 non-null  object
#  5   stop_datetime                        261874 non-null  object
#  6   duration_of_stop                     261874 non-null  object
#  7   is_stop_response_to_call             261874 non-null  object
#  8   location                             260127 non-null  object
#  9   district                             260724 non-null  object
#  10  city                                 261819 non-null  object
# ...

# %%
# Checking Descriptive Statistics
df.describe()
# Out:
#                doj_record_id person_number       unique_identifier  \
# count                 250093        261435                  261874
# unique                234410            40                  261874
# top     U380118190BE0A4FD377             1  U3801222595268195966_4
# freq                      39        244933                       1
#
#                   stop_data_record_status agency_ori            stop_datetime  \
# count                              261874     261874                   261874
# unique                                  5          1                   220118
# top     Completed - Successful Submission  CA0380100  2023-07-08T21:18:00.000
# freq                               259771     261874                       89
#
#        duration_of_stop is_stop_response_to_call                   location  \
# count            261874                   261874                     260127
# unique              533                        2                      79691
# ...

# %%
# Dropping point column because it is nested; will later combine latitude and longitude columns
df.drop(['point'],axis=1,inplace=True)

# %%
# Verifying that point column has been dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261874 entries, 0 to 261873
# Data columns (total 82 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   doj_record_id                        250093 non-null  object
#  1   person_number                        261435 non-null  object
#  2   unique_identifier                    261874 non-null  object
#  3   stop_data_record_status              261874 non-null  object
#  4   agency_ori                           261874 non-null  object
#  5   stop_datetime                        261874 non-null  object
#  6   duration_of_stop                     261874 non-null  object
#  7   is_stop_response_to_call             261874 non-null  object
#  8   location                             260127 non-null  object
#  9   district                             260724 non-null  object
#  10  city                                 261819 non-null  object
# ...

# %%
# Viewing unique values for each column
for column in df.columns:
    print(df[column].name)
    print(df[column].unique())
# Out:
# doj_record_id
# ['U3801182212099D51C75' 'U38011822213C974B0F8' 'U3801182217DE44A11D0' ...
#  'U3801211789C98DC43BA' 'U380121178475FC3361C' 'U3801211799A4A177F2A']
# person_number
# ['1' nan '2' '4' '15' '35' '13' '17' '7' '14' '18' '23' '5' '6' '11' '10'
#  '3' '8' '20' '37' '12' '9' '16' '30' '0' '36' '26' '33' '24' '19' '28'
#  '25' '31' '32' '21' '27' '29' '34' '22' '39' '38']
# unique_identifier
# ['U3801182212099D51C75_1' 'U38011822213C974B0F8_1'
#  'U3801182217DE44A11D0_1' ... 'U3801222358CEA13C6A5_4'
#  'U3801222353D9DC2C45C_4' 'U3801222595268195966_4']
# stop_data_record_status
# ['Completed - Successful Submission' 'In-progress' 'Ready for Submission'
#  'Deleted' 'No Further Information Available']
# agency_ori
# ['CA0380100']
# stop_datetime
# ['2018-08-09T16:05:00.000' '2018-08-09T23:15:00.000'
#  '2018-08-09T12:01:00.000' ... '2021-06-27T08:41:00.000'
#  '2021-06-27T17:29:00.000' '2021-06-28T13:40:00.000']
# duration_of_stop
# ...

# %%
# Checking for Duplicate Values
df.duplicated().sum()
# Out:
# 0

# %%
# Filling Null Values for is_location_k12_pub_school and nfia_flag with N for No
df['is_location_k12_pub_school']=df['is_location_k12_pub_school'].fillna('N')
df['nfia_flag']=df['nfia_flag'].fillna('N')

# %%
# Verifying that is_location_k12_pub_school and nfia_flag had their null values filled with N for No
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261874 entries, 0 to 261873
# Data columns (total 82 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   doj_record_id                        250093 non-null  object
#  1   person_number                        261435 non-null  object
#  2   unique_identifier                    261874 non-null  object
#  3   stop_data_record_status              261874 non-null  object
#  4   agency_ori                           261874 non-null  object
#  5   stop_datetime                        261874 non-null  object
#  6   duration_of_stop                     261874 non-null  object
#  7   is_stop_response_to_call             261874 non-null  object
#  8   location                             260127 non-null  object
#  9   district                             260724 non-null  object
#  10  city                                 261819 non-null  object
# ...

# %%
# Filling Null Values for certain columns with N/A for Non-Applicable
df['traffic_viol_cjis_off_code']=df['traffic_viol_cjis_off_code'].fillna('N/A')
df['traffic_viol_off_code']=df['traffic_viol_off_code'].fillna('N/A')
df['traffic_viol_off_statute']=df['traffic_viol_off_statute'].fillna('N/A')
df['traffic_viol_off_type']=df['traffic_viol_off_type'].fillna('N/A')
df['traffic_viol_off_type_charge']=df['traffic_viol_off_type_charge'].fillna('N/A')
df['traffic_violation_type']=df['traffic_violation_type'].fillna('N/A')
df['traffic_violation_type_code']=df['traffic_violation_type_code'].fillna('N/A')
df['warning_cjis_off_code']=df['warning_cjis_off_code'].fillna('N/A')
df['warning_off_code_txt']=df['warning_off_code_txt'].fillna('N/A')
df['warning_off_statute']=df['warning_off_statute'].fillna('N/A')
df['warning_off_type_charge']=df['warning_off_type_charge'].fillna('N/A')
df['warning_off_type_statute']=df['warning_off_type_statute'].fillna('N/A')
df['suspicion_cjis_off_code']=df['suspicion_cjis_off_code'].fillna('N/A')
df['suspicion_off_code_txt']=df['suspicion_off_code_txt'].fillna('N/A')
df['suspicion_off_statute']=df['suspicion_off_statute'].fillna('N/A')
df['suspicion_off_type_charge']=df['suspicion_off_type_charge'].fillna('N/A')
df['suspicion_off_type_statute']=df['suspicion_off_type_statute'].fillna('N/A')
df['suspicion_sub_type']=df['suspicion_sub_type'].fillna('N/A')
df['suspicion_sub_type_code']=df['suspicion_sub_type_code'].fillna('N/A')
df['citation_cjis_off_code']=df['citation_cjis_off_code'].fillna('N/A')
df['citation_off_code_txt']=df['citation_off_code_txt'].fillna('N/A')
df['citation_off_statute']=df['citation_off_statute'].fillna('N/A')
df['citation_off_type_charge']=df['citation_off_type_charge'].fillna('N/A')
df['citation_off_type_statute']=df['citation_off_type_statute'].fillna('N/A')
df['cite_release_cjis_off_c']=df['cite_release_cjis_off_c'].fillna('N/A')
df['cite_release_off_code_txt']=df['cite_release_off_code_txt'].fillna('N/A')
df['cite_release_off_statute']=df['cite_release_off_statute'].fillna('N/A')
df['cite_release_off_type_charge']=df['cite_release_off_type_charge'].fillna('N/A')
df['cite_release_off_type_statute']=df['cite_release_off_type_statute'].fillna('N/A')
df['basis_for_property_seizure']=df['basis_for_property_seizure'].fillna('N/A')
df['basis_for_property_seizure_code']=df['basis_for_property_seizure_code'].fillna('N/A')
df['basis_for_search']=df['basis_for_search'].fillna('N/A')
df['basis_for_search_code']=df['basis_for_search_code'].fillna('N/A')
df['cust_arrest_cjis_off_code']=df['cust_arrest_cjis_off_code'].fillna('N/A')
df['cust_arrest_off_code_txt']=df['cust_arrest_off_code_txt'].fillna('N/A')
df['cust_arrest_off_statute']=df['cust_arrest_off_statute'].fillna('N/A')
df['cust_arrest_off_type_charge']=df['cust_arrest_off_type_charge'].fillna('N/A')
df['cust_arrest_off_type_statute']=df['cust_arrest_off_type_statute'].fillna('N/A')
df['type_of_property_seized']=df['type_of_property_seized'].fillna('N/A')
df['type_of_property_seized_code']=df['type_of_property_seized_code'].fillna('N/A')
df['k_12_school_code']=df['k_12_school_code'].fillna('N/A')

# %%
# Verifying that certain columns had their null values filled with N/A for Non-Applicable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261874 entries, 0 to 261873
# Data columns (total 82 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   doj_record_id                        250093 non-null  object
#  1   person_number                        261435 non-null  object
#  2   unique_identifier                    261874 non-null  object
#  3   stop_data_record_status              261874 non-null  object
#  4   agency_ori                           261874 non-null  object
#  5   stop_datetime                        261874 non-null  object
#  6   duration_of_stop                     261874 non-null  object
#  7   is_stop_response_to_call             261874 non-null  object
#  8   location                             260127 non-null  object
#  9   district                             260724 non-null  object
#  10  city                                 261819 non-null  object
# ...

# %%
# Combine latitude and longitude columns
df['coordinates'] = df['latitude'].astype('object') + ', ' + df['longitude'].astype('object')

# %%
# Verifying that latitude and longitude columns were combined into a single column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261874 entries, 0 to 261873
# Data columns (total 83 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   doj_record_id                        250093 non-null  object
#  1   person_number                        261435 non-null  object
#  2   unique_identifier                    261874 non-null  object
#  3   stop_data_record_status              261874 non-null  object
#  4   agency_ori                           261874 non-null  object
#  5   stop_datetime                        261874 non-null  object
#  6   duration_of_stop                     261874 non-null  object
#  7   is_stop_response_to_call             261874 non-null  object
#  8   location                             260127 non-null  object
#  9   district                             260724 non-null  object
#  10  city                                 261819 non-null  object
# ...

# %%
# Fill Null Values for perceived_gender_nonconforming_code to N/A for Non-Applicable
df['perceived_gender_nonconforming_code']=df['perceived_gender_nonconforming_code'].fillna('N/A')

# %%
# Verifying that null values for perceived_gender_nonconforming_code was filled with N/A for Non-Applicable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261874 entries, 0 to 261873
# Data columns (total 83 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   doj_record_id                        250093 non-null  object
#  1   person_number                        261435 non-null  object
#  2   unique_identifier                    261874 non-null  object
#  3   stop_data_record_status              261874 non-null  object
#  4   agency_ori                           261874 non-null  object
#  5   stop_datetime                        261874 non-null  object
#  6   duration_of_stop                     261874 non-null  object
#  7   is_stop_response_to_call             261874 non-null  object
#  8   location                             260127 non-null  object
#  9   district                             260724 non-null  object
#  10  city                                 261819 non-null  object
# ...

# %%
# Dropping lea_record_id, latitude, and longitude columns
df.drop(['lea_record_id','latitude','longitude'],axis=1,inplace=True)

# %%
# Verifying that lea_record_id, latitude, and longitude columns were dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261874 entries, 0 to 261873
# Data columns (total 80 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   doj_record_id                        250093 non-null  object
#  1   person_number                        261435 non-null  object
#  2   unique_identifier                    261874 non-null  object
#  3   stop_data_record_status              261874 non-null  object
#  4   agency_ori                           261874 non-null  object
#  5   stop_datetime                        261874 non-null  object
#  6   duration_of_stop                     261874 non-null  object
#  7   is_stop_response_to_call             261874 non-null  object
#  8   location                             260127 non-null  object
#  9   district                             260724 non-null  object
#  10  city                                 261819 non-null  object
# ...

# %%
# Doing df.dropna for all other Null Values
df.dropna(inplace=True)

# %%
# Verifying that all other Null Values have been dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215312 entries, 0 to 261844
# Data columns (total 80 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   doj_record_id                        215312 non-null  object
#  1   person_number                        215312 non-null  object
#  2   unique_identifier                    215312 non-null  object
#  3   stop_data_record_status              215312 non-null  object
#  4   agency_ori                           215312 non-null  object
#  5   stop_datetime                        215312 non-null  object
#  6   duration_of_stop                     215312 non-null  object
#  7   is_stop_response_to_call             215312 non-null  object
#  8   location                             215312 non-null  object
#  9   district                             215312 non-null  object
#  10  city                                 215312 non-null  object
# ...

# %%
# Change data types for certain columns
df['person_number']=df['person_number'].astype('int64')
df['stop_datetime']=df['stop_datetime'].astype('datetime64[ns]')
df['duration_of_stop']=df['duration_of_stop'].astype('int64')
df['perceived_age']=df['perceived_age'].astype('int64')
df['data_as_of']=df['data_as_of'].astype('datetime64[ns]')
df['data_loaded_at']=df['data_loaded_at'].astype('datetime64[ns]')

# %%
# Verifying that data types for certain columns was changed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215312 entries, 0 to 261844
# Data columns (total 80 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   doj_record_id                        215312 non-null  object
#  1   person_number                        215312 non-null  int64
#  2   unique_identifier                    215312 non-null  object
#  3   stop_data_record_status              215312 non-null  object
#  4   agency_ori                           215312 non-null  object
#  5   stop_datetime                        215312 non-null  datetime64[ns]
#  6   duration_of_stop                     215312 non-null  int64
#  7   is_stop_response_to_call             215312 non-null  object
#  8   location                             215312 non-null  object
#  9   district                             215312 non-null  object
#  10  city                                 215312 non-null  object
# ...

# %%
# Checking Descriptive Statistics now that DataFrame has been cleaned
df.describe()
# Out:
#        person_number                  stop_datetime  duration_of_stop  \
# count  215312.000000                         215312     215312.000000
# mean        1.111703  2019-12-15 16:17:07.420023040         21.513357
# min         1.000000            2018-07-01 00:01:00          1.000000
# 25%         1.000000            2019-01-06 14:57:00          7.000000
# 50%         1.000000            2019-08-11 11:24:00         10.000000
# 75%         1.000000            2020-08-08 00:32:45         20.000000
# max        39.000000            2023-06-28 08:06:00       1440.000000
# std         0.683341                            NaN         52.541321
#
#        perceived_age                     data_as_of  \
# count  215312.000000                         215312
# mean       36.912337  2023-08-04 00:47:08.719142400
# min         1.000000            2023-08-02 11:46:29
# 25%        28.000000            2023-08-02 11:46:31
# 50%        35.000000            2023-08-02 11:46:39
# ...

# %%
# Checking Descriptive Statistics now that DataFrame has been cleaned, but this time, with non-numeric data
df.describe(include=object)
# Out:
#                doj_record_id        unique_identifier  \
# count                 215312                   215312
# unique                200945                   215312
# top     U380118190BE0A4FD377  U380120155D44A03FF02_15
# freq                      39                        1
#
#                   stop_data_record_status agency_ori is_stop_response_to_call  \
# count                              215312     215312                   215312
# unique                                  5          1                        2
# top     Completed - Successful Submission  CA0380100                        N
# freq                               214511     215312                   160943
#
#                          location  district           city  \
# count                      215312    215312         215312
# unique                      61145        12             38
# top     FUNSTON AVE / CABRILLO ST  SOUTHERN  SAN FRANCISCO
# freq                         2841     34875         213690
#
# ...

# %%
# Cleaned San Francisco API DataFrame
df
# Out:
#                doj_record_id  person_number        unique_identifier  \
# 0       U3801182212099D51C75              1   U3801182212099D51C75_1
# 1       U38011822213C974B0F8              1   U38011822213C974B0F8_1
# 2       U3801182217DE44A11D0              1   U3801182217DE44A11D0_1
# 3       U3801182216E4F98E00B              1   U3801182216E4F98E00B_1
# 4       U380118222EAA40B9919              1   U380118222EAA40B9919_1
# ...                      ...            ...                      ...
# 261840   U380119280A79BE3BFB              8    U380119280A79BE3BFB_8
# 261841  U380120068DC072780FF              6   U380120068DC072780FF_6
# 261842  U380120330C5D4B126DC              6   U380120330C5D4B126DC_6
# 261843  U3801200723F9EBA4A39             15  U3801200723F9EBA4A39_15
# 261844  U380120155D44A03FF02             15  U380120155D44A03FF02_15
#
#                   stop_data_record_status agency_ori       stop_datetime  \
# ...

# %%
# Checking Null Values and Data Types
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# ...

# %%
# Checking Descriptive Statistics
df2.describe()
# Out:
#        county_name  driver_age_raw    driver_age
# count          0.0    86414.000000  86120.000000
# mean           NaN     1970.491228     34.011333
# std            NaN      110.914909     12.738564
# min            NaN        0.000000     15.000000
# 25%            NaN     1967.000000     23.000000
# 50%            NaN     1980.000000     31.000000
# 75%            NaN     1987.000000     43.000000
# max            NaN     8801.000000     99.000000

# %%
# Checking Descriptive Statistics just this time with the non-numerical data
df2.describe(include=object)
# Out:
#          stop_date stop_time driver_gender driver_race violation_raw  \
# count        91741     91741         86406       86408         86408
# unique        3768      1436             2           5            12
# top     2012-01-11     11:00             M       White      Speeding
# freq            69       323         62895       62158         48463
#
#        violation         search_type stop_outcome is_arrested stop_duration
# count      86408                3196        86408       86408         86408
# unique         6                  24            6           2             5
# top     Speeding  Incident to Arrest     Citation       False      0-15 Min
# freq       48463                1219        77006       83479         69543

# %%
# Checking Null Values
df2.isna().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
# Viewing unique values for each column
for column in df2.columns:
    print(df2[column].name)
    print(df2[column].unique())
# Out:
# stop_date
# ['2005-01-02' '2005-01-18' '2005-01-23' ... '2015-12-29' '2015-12-30'
#  '2015-12-31']
# stop_time
# ['01:55' '08:15' '23:15' ... '04:42' '04:59' '05:35']
# county_name
# [nan]
# driver_gender
# ['M' 'F' nan]
# driver_age_raw
# [1985. 1965. 1972. 1986. 1984. 1982. 1969. 1970. 1979. 1966. 1955. 1958.
#  1953. 1967.   nan 1964. 1977. 1959. 1973. 1947. 1978. 1962. 1981. 1988.
#  1983. 1961. 1957. 1971. 1950. 1954. 1960. 1976. 1974. 1968. 1938. 1980.
#  1963. 1975. 1987. 1948. 1956. 1944. 1935.    0. 1952. 1945. 1946. 1941.
#  1942. 1951. 1949. 2005. 1939. 1943. 1936. 1924. 1937. 1929. 1930. 1931.
#  1923. 1940. 1933. 1989. 1928. 1932. 1990. 1926. 2006. 1927. 1997. 1934.
#  1887. 1925. 1918. 2004. 1991. 2002. 2007. 1992. 8801. 2001. 2003. 1998.
#  1922. 1993. 2008. 2009. 2919. 2000. 1994. 1995. 2011. 1996. 2013. 1914.
#  1920. 1999.]
# driver_age
# [20. 40. 33. 19. 21. 23. 36. 35. 26. 39. 50. 47. 52. 38. nan 41. 28. 46.
# ...

# %%
# Dropping county_name and search_type columns
df2.drop(['county_name','search_type'],axis=1,inplace=True)

# %%
# Verifying that county_name and search_type columns have been dropped
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   driver_gender       86406 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   stop_outcome        86408 non-null  object
#  10  is_arrested         86408 non-null  object
#  11  stop_duration       86408 non-null  object
#  12  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(2), object(9)
# memory usage: 7.9+ MB

# %%
# Doing df2.dropna on all other Null Values
df2.dropna(inplace=True)

# %%
# Verifying that all other Null Values have been dropped
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86113 entries, 0 to 91740
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           86113 non-null  object
#  1   stop_time           86113 non-null  object
#  2   driver_gender       86113 non-null  object
#  3   driver_age_raw      86113 non-null  float64
#  4   driver_age          86113 non-null  float64
#  5   driver_race         86113 non-null  object
#  6   violation_raw       86113 non-null  object
#  7   violation           86113 non-null  object
#  8   search_conducted    86113 non-null  bool
#  9   stop_outcome        86113 non-null  object
#  10  is_arrested         86113 non-null  object
#  11  stop_duration       86113 non-null  object
#  12  drugs_related_stop  86113 non-null  bool
# dtypes: bool(2), float64(2), object(9)
# memory usage: 8.0+ MB

# %%
# Changing Data Types for driver_age_raw and driver_age to int64
df2['driver_age_raw']=df2['driver_age_raw'].astype('int64')
df2['driver_age']=df2['driver_age'].astype('int64')

# %%
# Verifying that data types for driver_age_raw and driver_age have been changed to int64
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86113 entries, 0 to 91740
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           86113 non-null  object
#  1   stop_time           86113 non-null  object
#  2   driver_gender       86113 non-null  object
#  3   driver_age_raw      86113 non-null  int64
#  4   driver_age          86113 non-null  int64
#  5   driver_race         86113 non-null  object
#  6   violation_raw       86113 non-null  object
#  7   violation           86113 non-null  object
#  8   search_conducted    86113 non-null  bool
#  9   stop_outcome        86113 non-null  object
#  10  is_arrested         86113 non-null  object
#  11  stop_duration       86113 non-null  object
#  12  drugs_related_stop  86113 non-null  bool
# dtypes: bool(2), int64(2), object(9)
# memory usage: 8.0+ MB

# %%
# Checking Descriptive Statistics now that DataFrame has been cleaned
df2.describe()
# Out:
#        driver_age_raw    driver_age
# count    86113.000000  86113.000000
# mean      1976.268299     34.011868
# std         13.063514     12.738786
# min       1914.000000     15.000000
# 25%       1967.000000     23.000000
# 50%       1980.000000     31.000000
# 75%       1987.000000     43.000000
# max       1999.000000     99.000000

# %%
# Checking Descriptive Statistics now that DataFrame has been cleaned, but this time, with non-numeric data
df2.describe(include=object)
# Out:
#          stop_date stop_time driver_gender driver_race violation_raw  \
# count        86113     86113         86113       86113         86113
# unique        3767      1432             2           5            12
# top     2012-02-28     10:00             M       White      Speeding
# freq            64       299         62649       61947         48359
#
#        violation stop_outcome is_arrested stop_duration
# count      86113        86113       86113         86113
# unique         6            6           2             5
# top     Speeding     Citation       False      0-15 Min
# freq       48359        76821       83188         69334

# %%
# Cleaned Rhode Island Kaggle DataFrame
df2
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M            1985          20
# 1      2005-01-18     08:15             M            1965          40
# 2      2005-01-23     23:15             M            1972          33
# 3      2005-02-20     17:15             M            1986          19
# 4      2005-03-14     10:00             F            1984          21
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M            1986          29
# 91737  2015-12-31     20:35             F            1982          33
# 91738  2015-12-31     20:45             M            1992          23
# 91739  2015-12-31     21:42             M            1993          22
# 91740  2015-12-31     22:46             M            1959          56
#
#       driver_race                   violation_raw         violation  \
# ...
